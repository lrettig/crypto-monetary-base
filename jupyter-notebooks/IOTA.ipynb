# %%
# Load project functions
import crypto_monetary_base as cmb

# %%
import pandas as pd
import datetime
from tqdm import tqdm_notebook

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set()
plt.rcParams['figure.figsize'] = (6, 4)
plt.rcParams['axes.labelpad'] = 10
mpl.rc('text', usetex=True)
plt.style.use('ggplot')

from IPython.display import display

# %%
# %load_ext version_information
# %version_information pandas, matplotlib, seaborn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/share/virtualenvs/crypto-monetary-base-xxmj4jsc/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/share/virtualenvs/crypto-monetary-base-xxmj4jsc/lib/python3.9/site-packages/version_information/version_information.py in _repr_html_(self)
#     126         html += "<tr><th>Software</th><th>Version</th></tr>"
#     127         for name, version in self.packages:
# --> 128             _version = cgi.escape(version)
#     129             html += "<tr><td>%s</td><td>%s</td></tr>" % (name, _version)
#     130
#
# AttributeError: module 'cgi' has no attribute 'escape'
# Software versions
# Python 3.9.1 64bit [GCC 5.4.0 20160609]
# IPython 7.19.0
# OS Linux 5.8.0 0.bpo.2 amd64 x86_64 with glibc2.28
# pandas 1.2.0
# matplotlib 3.3.3
# seaborn 0.11.1
# Sun Jan 10 13:40:37 2021 EST

# %% [markdown]
# ## Supply Curve Calculation

# %%
COIN_SYMBOL = 'IOTA'

# %%
supply = cmb.datetime_constant_supply_curve(
    start_date=datetime.date(2017, 6, 14),
    num_weeks=6350,
    supply_amount=2779530283,
    pct_distributed=0.95,
)

display(supply.head())
display(supply.tail())

cmb.plot_constant_supply_curve(
    supply,
    'IOTA',
    out_name='IOTA',
    ylim=(0, 115),
);
# Out:
#    total_supply  distributed_supply  total_supply_pct  distributed_supply_pct  \
# 0    2779530283        2.640554e+09             100.0                    95.0
# 1    2779530283        2.640554e+09             100.0                    95.0
# 2    2779530283        2.640554e+09             100.0                    95.0
# 3    2779530283        2.640554e+09             100.0                    95.0
# 4    2779530283        2.640554e+09             100.0                    95.0
#
#         date
# 0 2017-06-18
# 1 2017-06-25
# 2 2017-07-02
# 3 2017-07-09
# 4 2017-07-16
#       total_supply  distributed_supply  total_supply_pct  \
# 6345    2779530283        2.640554e+09             100.0
# 6346    2779530283        2.640554e+09             100.0
# 6347    2779530283        2.640554e+09             100.0
# 6348    2779530283        2.640554e+09             100.0
# 6349    2779530283        2.640554e+09             100.0
#
#       distributed_supply_pct       date
# 6345                    95.0 2139-01-25
# 6346                    95.0 2139-02-01
# 6347                    95.0 2139-02-08
# 6348                    95.0 2139-02-15
# 6349                    95.0 2139-02-22
# <module 'matplotlib.pyplot' from '/home/lane/.local/share/virtualenvs/crypto-monetary-base-xxmj4jsc/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Standardize Time Series

# %%
weekly_supply = cmb.transform_supply(supply, COIN_SYMBOL, freq='weekly')

display(weekly_supply.head())
display(weekly_supply.tail())
# Out:
# Wrote 6350 lines to file ../output-data/IOTA_weekly.csv
#    coin  total_supply  distributed_supply  total_supply_pct  \
# 0  IOTA    2779530283        2.640554e+09             100.0
# 1  IOTA    2779530283        2.640554e+09             100.0
# 2  IOTA    2779530283        2.640554e+09             100.0
# 3  IOTA    2779530283        2.640554e+09             100.0
# 4  IOTA    2779530283        2.640554e+09             100.0
#
#    distributed_supply_pct        date
# 0                    95.0  2017-06-01
# 1                    95.0  2017-06-01
# 2                    95.0  2017-07-01
# 3                    95.0  2017-07-01
# 4                    95.0  2017-07-01
#       coin  total_supply  distributed_supply  total_supply_pct  \
# 6345  IOTA    2779530283        2.640554e+09             100.0
# 6346  IOTA    2779530283        2.640554e+09             100.0
# 6347  IOTA    2779530283        2.640554e+09             100.0
# 6348  IOTA    2779530283        2.640554e+09             100.0
# 6349  IOTA    2779530283        2.640554e+09             100.0
#
#       distributed_supply_pct        date
# 6345                    95.0  2139-01-01
# 6346                    95.0  2139-02-01
# 6347                    95.0  2139-02-01
# 6348                    95.0  2139-02-01
# 6349                    95.0  2139-02-01

# %%
monthly_supply = cmb.transform_supply(supply, COIN_SYMBOL, freq='monthly')

display(monthly_supply.head())
display(monthly_supply.tail())
# Out:
# Wrote 1461 lines to file ../output-data/IOTA_monthly.csv
#    coin  total_supply  distributed_supply  total_supply_pct  \
# 0  IOTA    2779530283        2.640554e+09             100.0
# 1  IOTA    2779530283        2.640554e+09             100.0
# 2  IOTA    2779530283        2.640554e+09             100.0
# 3  IOTA    2779530283        2.640554e+09             100.0
# 4  IOTA    2779530283        2.640554e+09             100.0
#
#    distributed_supply_pct        date
# 0                    95.0  2017-06-01
# 1                    95.0  2017-07-01
# 2                    95.0  2017-08-01
# 3                    95.0  2017-09-01
# 4                    95.0  2017-10-01
#       coin  total_supply  distributed_supply  total_supply_pct  \
# 1456  IOTA    2779530283        2.640554e+09             100.0
# 1457  IOTA    2779530283        2.640554e+09             100.0
# 1458  IOTA    2779530283        2.640554e+09             100.0
# 1459  IOTA    2779530283        2.640554e+09             100.0
# 1460  IOTA    2779530283        2.640554e+09             100.0
#
#       distributed_supply_pct        date
# 1456                    95.0  2138-10-01
# 1457                    95.0  2138-11-01
# 1458                    95.0  2138-12-01
# 1459                    95.0  2139-01-01
# 1460                    95.0  2139-02-01

# %%
yearly_supply = cmb.transform_supply(supply, COIN_SYMBOL, freq='yearly')

display(yearly_supply.head())
display(yearly_supply.tail())
# Out:
# Wrote 123 lines to file ../output-data/IOTA_yearly.csv
#    coin  total_supply  distributed_supply  total_supply_pct  \
# 0  IOTA    2779530283        2.640554e+09             100.0
# 1  IOTA    2779530283        2.640554e+09             100.0
# 2  IOTA    2779530283        2.640554e+09             100.0
# 3  IOTA    2779530283        2.640554e+09             100.0
# 4  IOTA    2779530283        2.640554e+09             100.0
#
#    distributed_supply_pct        date
# 0                    95.0  2017-06-01
# 1                    95.0  2018-01-01
# 2                    95.0  2019-01-01
# 3                    95.0  2020-01-01
# 4                    95.0  2021-01-01
#      coin  total_supply  distributed_supply  total_supply_pct  \
# 118  IOTA    2779530283        2.640554e+09             100.0
# 119  IOTA    2779530283        2.640554e+09             100.0
# 120  IOTA    2779530283        2.640554e+09             100.0
# 121  IOTA    2779530283        2.640554e+09             100.0
# 122  IOTA    2779530283        2.640554e+09             100.0
#
#      distributed_supply_pct        date
# 118                    95.0  2135-01-01
# 119                    95.0  2136-01-01
# 120                    95.0  2137-01-01
# 121                    95.0  2138-01-01
# 122                    95.0  2139-01-01
