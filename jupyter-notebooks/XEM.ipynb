# %%
# Load project functions
import crypto_monetary_base as cmb

# %%
import pandas as pd
import datetime
from tqdm import tqdm_notebook

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set()
plt.rcParams['figure.figsize'] = (6, 4)
plt.rcParams['axes.labelpad'] = 10
mpl.rc('text', usetex=True)
plt.style.use('ggplot')

from IPython.display import display

# %%
# %load_ext version_information
# %version_information pandas, matplotlib, seaborn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/share/virtualenvs/crypto-monetary-base-xxmj4jsc/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/share/virtualenvs/crypto-monetary-base-xxmj4jsc/lib/python3.9/site-packages/version_information/version_information.py in _repr_html_(self)
#     126         html += "<tr><th>Software</th><th>Version</th></tr>"
#     127         for name, version in self.packages:
# --> 128             _version = cgi.escape(version)
#     129             html += "<tr><td>%s</td><td>%s</td></tr>" % (name, _version)
#     130
#
# AttributeError: module 'cgi' has no attribute 'escape'
# Software versions
# Python 3.9.1 64bit [GCC 5.4.0 20160609]
# IPython 7.19.0
# OS Linux 5.8.0 0.bpo.2 amd64 x86_64 with glibc2.28
# pandas 1.2.0
# matplotlib 3.3.3
# seaborn 0.11.1
# Sun Jan 10 13:42:30 2021 EST

# %% [markdown]
# ## Supply Curve Calculation

# %%
COIN_SYMBOL = 'XEM'

# %%
supply = cmb.datetime_constant_supply_curve(
    start_date=datetime.date(2015, 4, 1),
    num_weeks=6350,
    supply_amount=8999999999,
    pct_distributed=0.7,
)

display(supply.head())
display(supply.tail())

cmb.plot_constant_supply_curve(
    supply,
    'XEM',
    out_name='XEM',
    ylim=(0, 115),
)
# Out:
#    total_supply  distributed_supply  total_supply_pct  distributed_supply_pct  \
# 0    8999999999        6.300000e+09             100.0                    70.0
# 1    8999999999        6.300000e+09             100.0                    70.0
# 2    8999999999        6.300000e+09             100.0                    70.0
# 3    8999999999        6.300000e+09             100.0                    70.0
# 4    8999999999        6.300000e+09             100.0                    70.0
#
#         date
# 0 2015-04-05
# 1 2015-04-12
# 2 2015-04-19
# 3 2015-04-26
# 4 2015-05-03
#       total_supply  distributed_supply  total_supply_pct  \
# 6345    8999999999        6.300000e+09             100.0
# 6346    8999999999        6.300000e+09             100.0
# 6347    8999999999        6.300000e+09             100.0
# 6348    8999999999        6.300000e+09             100.0
# 6349    8999999999        6.300000e+09             100.0
#
#       distributed_supply_pct       date
# 6345                    70.0 2136-11-11
# 6346                    70.0 2136-11-18
# 6347                    70.0 2136-11-25
# 6348                    70.0 2136-12-02
# 6349                    70.0 2136-12-09
# <module 'matplotlib.pyplot' from '/home/lane/.local/share/virtualenvs/crypto-monetary-base-xxmj4jsc/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ## Standardize Time Series

# %%
weekly_supply = cmb.transform_supply(supply, COIN_SYMBOL, freq='weekly')

display(weekly_supply.head())
display(weekly_supply.tail())
# Out:
# Wrote 6350 lines to file ../output-data/XEM_weekly.csv
#   coin  total_supply  distributed_supply  total_supply_pct  \
# 0  XEM    8999999999        6.300000e+09             100.0
# 1  XEM    8999999999        6.300000e+09             100.0
# 2  XEM    8999999999        6.300000e+09             100.0
# 3  XEM    8999999999        6.300000e+09             100.0
# 4  XEM    8999999999        6.300000e+09             100.0
#
#    distributed_supply_pct        date
# 0                    70.0  2015-04-01
# 1                    70.0  2015-04-01
# 2                    70.0  2015-04-01
# 3                    70.0  2015-04-01
# 4                    70.0  2015-05-01
#      coin  total_supply  distributed_supply  total_supply_pct  \
# 6345  XEM    8999999999        6.300000e+09             100.0
# 6346  XEM    8999999999        6.300000e+09             100.0
# 6347  XEM    8999999999        6.300000e+09             100.0
# 6348  XEM    8999999999        6.300000e+09             100.0
# 6349  XEM    8999999999        6.300000e+09             100.0
#
#       distributed_supply_pct        date
# 6345                    70.0  2136-11-01
# 6346                    70.0  2136-11-01
# 6347                    70.0  2136-11-01
# 6348                    70.0  2136-12-01
# 6349                    70.0  2136-12-01

# %%
monthly_supply = cmb.transform_supply(supply, COIN_SYMBOL, freq='monthly')

display(monthly_supply.head())
display(monthly_supply.tail())
# Out:
# Wrote 1461 lines to file ../output-data/XEM_monthly.csv
#   coin  total_supply  distributed_supply  total_supply_pct  \
# 0  XEM    8999999999        6.300000e+09             100.0
# 1  XEM    8999999999        6.300000e+09             100.0
# 2  XEM    8999999999        6.300000e+09             100.0
# 3  XEM    8999999999        6.300000e+09             100.0
# 4  XEM    8999999999        6.300000e+09             100.0
#
#    distributed_supply_pct        date
# 0                    70.0  2015-04-01
# 1                    70.0  2015-05-01
# 2                    70.0  2015-06-01
# 3                    70.0  2015-07-01
# 4                    70.0  2015-08-01
#      coin  total_supply  distributed_supply  total_supply_pct  \
# 1456  XEM    8999999999        6.300000e+09             100.0
# 1457  XEM    8999999999        6.300000e+09             100.0
# 1458  XEM    8999999999        6.300000e+09             100.0
# 1459  XEM    8999999999        6.300000e+09             100.0
# 1460  XEM    8999999999        6.300000e+09             100.0
#
#       distributed_supply_pct        date
# 1456                    70.0  2136-08-01
# 1457                    70.0  2136-09-01
# 1458                    70.0  2136-10-01
# 1459                    70.0  2136-11-01
# 1460                    70.0  2136-12-01

# %%
yearly_supply = cmb.transform_supply(supply, COIN_SYMBOL, freq='yearly')

display(yearly_supply.head())
display(yearly_supply.tail())
# Out:
# Wrote 122 lines to file ../output-data/XEM_yearly.csv
#   coin  total_supply  distributed_supply  total_supply_pct  \
# 0  XEM    8999999999        6.300000e+09             100.0
# 1  XEM    8999999999        6.300000e+09             100.0
# 2  XEM    8999999999        6.300000e+09             100.0
# 3  XEM    8999999999        6.300000e+09             100.0
# 4  XEM    8999999999        6.300000e+09             100.0
#
#    distributed_supply_pct        date
# 0                    70.0  2015-04-01
# 1                    70.0  2016-01-01
# 2                    70.0  2017-01-01
# 3                    70.0  2018-01-01
# 4                    70.0  2019-01-01
#     coin  total_supply  distributed_supply  total_supply_pct  \
# 117  XEM    8999999999        6.300000e+09             100.0
# 118  XEM    8999999999        6.300000e+09             100.0
# 119  XEM    8999999999        6.300000e+09             100.0
# 120  XEM    8999999999        6.300000e+09             100.0
# 121  XEM    8999999999        6.300000e+09             100.0
#
#      distributed_supply_pct        date
# 117                    70.0  2132-01-01
# 118                    70.0  2133-01-01
# 119                    70.0  2134-01-01
# 120                    70.0  2135-01-01
# 121                    70.0  2136-01-01
